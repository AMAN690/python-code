# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

# %%
lr = LogisticRegression()
svc = LinearSVC(C=1.0)
rfc = RandomForestClassifier(n_estimators=100)

# %%
pima = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/MASS/Pima.te.csv")

# %%
pima.head(5)
# Out:
#    Unnamed: 0  npreg  glu  bp  skin   bmi    ped  age type
# 0           1      6  148  72    35  33.6  0.627   50  Yes
# 1           2      1   85  66    29  26.6  0.351   31   No
# 2           3      1   89  66    23  28.1  0.167   21   No
# 3           4      3   78  50    32  31.0  0.248   26  Yes
# 4           5      2  197  70    45  30.5  0.158   53  Yes

# %%
pima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  332 non-null    int64
#  1   npreg       332 non-null    int64
#  2   glu         332 non-null    int64
#  3   bp          332 non-null    int64
#  4   skin        332 non-null    int64
#  5   bmi         332 non-null    float64
#  6   ped         332 non-null    float64
#  7   age         332 non-null    int64
#  8   type        332 non-null    object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 23.5+ KB

# %%
pima.shape
# Out:
# (332, 9)

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(pima, test_size=0.2)

# %%
train.shape
# Out:
# (265, 9)

# %%
train.head(3)
# Out:
#      Unnamed: 0  npreg  glu  bp  skin   bmi    ped  age type
# 116         117     10  101  86    37  45.6  1.136   38  Yes
# 88           89      5  109  62    41  35.8  0.514   25  Yes
# 315         316      2   99  60    17  36.6  0.453   21   No

# %%
test.shape
# Out:
# (67, 9)

# %%
train.iloc[:,:8].head(5)
# Out:
#      Unnamed: 0  npreg  glu  bp  skin   bmi    ped  age
# 116         117     10  101  86    37  45.6  1.136   38
# 88           89      5  109  62    41  35.8  0.514   25
# 315         316      2   99  60    17  36.6  0.453   21
# 312         313      2  106  56    27  29.0  0.426   22
# 56           57      1   88  30    42  55.0  0.496   26

# %%
train_feat = train.iloc[:,:8]

# %%
train_feat.shape
# Out:
# (265, 8)

# %%
train_targ = train['ped']

# %%
train[['ped']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 265 entries, 116 to 265
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ped     265 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-020c327bc800> in <module>()
# ----> 1 lr.fit(train_feat,train_targ)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1527                          accept_large_sparse=solver != 'liblinear')
# -> 1528         check_classification_targets(y)
#    1529         self.classes_ = np.unique(y)
#    1530         n_samples, n_features = X.shape
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'continuous'
